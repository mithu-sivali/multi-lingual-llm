# %%
# !PYTHONPATH=$PYTHONPATH:/home/ubuntu/suriya/speech-benchmarks/vits python examples/mms/tts/infer.py --model-dir /home/ubuntu/suriya/speech-benchmarks/models/tam \
--wav ./example.wav --txt "சென<0bcd>னை விமான நிலையத<0bcd>தில<0bcd> ஒரு கிலோ தங<0bcd>கம<0bcd> பறிமுதல<0bcd>"
# Out:
# python: can't open file '/home/ubuntu/suriya/speech-benchmarks/notebooks/examples/mms/tts/infer.py': [Errno 2] No such file or directory

# %%
# %cd ../fairseq
# Out:
# /home/ubuntu/suriya/speech-benchmarks/fairseq
# /home/ubuntu/suriya/speech-benchmarks/venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !PYTHONPATH=$PYTHONPATH:/home/ubuntu/suriya/speech-benchmarks/vits python examples/mms/tts/infer.py --model-dir /home/ubuntu/suriya/speech-benchmarks/models/tam \
--wav ./example.wav --txt "My தம்பி and I play கிரிக்கெட் இன்னிக்கு evening."
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1039)
#            2	LOAD_FAST(arg=0, lineno=1042)
#            4	LOAD_CONST(arg=1, lineno=1042)
#            6	BINARY_SUBSCR(arg=None, lineno=1042)
#            8	LOAD_FAST(arg=0, lineno=1042)
#           10	LOAD_CONST(arg=2, lineno=1042)
#           12	BINARY_SUBSCR(arg=None, lineno=1042)
#           14	COMPARE_OP(arg=4, lineno=1042)
#           16	LOAD_FAST(arg=0, lineno=1042)
#           18	LOAD_CONST(arg=1, lineno=1042)
#           20	BINARY_SUBSCR(arg=None, lineno=1042)
#           22	LOAD_FAST(arg=0, lineno=1042)
#           24	LOAD_CONST(arg=3, lineno=1042)
#           26	BINARY_SUBSCR(arg=None, lineno=1042)
#           28	COMPARE_OP(arg=5, lineno=1042)
#           30	BINARY_AND(arg=None, lineno=1042)
#           32	RETURN_VALUE(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# ...

# %%
import pandas as pd
df = pd.read_csv('../dataset/tamil-tts/tamil.csv')

# %%
import sys
import subprocess

count = 0

for i in df["transcript"]:
    
    theproc = subprocess.Popen(f'PYTHONPATH=$PYTHONPATH:/home/ubuntu/suriya/speech-benchmarks/vits python examples/mms/tts/infer.py --model-dir /home/ubuntu/suriya/speech-benchmarks/models/tam \
    --wav ../dataset/mms-tts/{count}.wav --txt \"{i}\"', shell = True)
    theproc.communicate() 
    count+=1
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1039)
#            2	LOAD_FAST(arg=0, lineno=1042)
#            4	LOAD_CONST(arg=1, lineno=1042)
#            6	BINARY_SUBSCR(arg=None, lineno=1042)
#            8	LOAD_FAST(arg=0, lineno=1042)
#           10	LOAD_CONST(arg=2, lineno=1042)
#           12	BINARY_SUBSCR(arg=None, lineno=1042)
#           14	COMPARE_OP(arg=4, lineno=1042)
#           16	LOAD_FAST(arg=0, lineno=1042)
#           18	LOAD_CONST(arg=1, lineno=1042)
#           20	BINARY_SUBSCR(arg=None, lineno=1042)
#           22	LOAD_FAST(arg=0, lineno=1042)
#           24	LOAD_CONST(arg=3, lineno=1042)
#           26	BINARY_SUBSCR(arg=None, lineno=1042)
#           28	COMPARE_OP(arg=5, lineno=1042)
#           30	BINARY_AND(arg=None, lineno=1042)
#           32	RETURN_VALUE(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# ...

# %%
from IPython.display import Audio

Audio("../dataset/openai-tts/12.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip freeze
# Out:
# absl-py==2.1.0
# accelerate==0.31.0
# aiohttp==3.9.5
# aiosignal==1.3.1
# alembic==1.13.1
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.4.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asteroid-filterbanks==0.4.0
# asttokens==2.4.1
# async-lru==2.0.4
# async-timeout==4.0.3
# attrs==23.2.0
# audioread==3.0.1
# Babel==2.15.0
# beautifulsoup4==4.12.3
# bibtexparser==2.0.0b7
# bleach==6.1.0
# certifi==2024.6.2
# cffi==1.16.0
# charset-normalizer==3.3.2
# click==8.1.7
# clldutils==3.22.2
# colorama==0.4.6
# colorlog==6.8.2
# comm==0.2.2
# contourpy==1.2.1
# csvw==3.3.0
# cycler==0.12.1
# Cython==3.0.10
# debugpy==1.8.1
# decorator==5.1.1
# defusedxml==0.7.1
# distro==1.9.0
# dlinfo==1.2.1
# docopt==0.6.2
# einops==0.8.0
# elevenlabs==1.3.1
# exceptiongroup==1.2.1
# executing==2.0.1
# fastjsonschema==2.20.0
# filelock==3.15.1
# fonttools==4.53.0
# fqdn==1.5.1
# frozenlist==1.4.1
# fsspec==2024.6.0
# greenlet==3.0.3
# grpcio==1.64.1
# ...
